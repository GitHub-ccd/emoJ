# %% [markdown]
# # Capstone Project - Journal of Emotion
#
# - __Student name: Chamila Dharmawardhana__
# - __Student pace: Full time__
# - __Scheduled project review date: July 28, 2020__
# - __Instructor name: Amber Yandow__
#
#
#
# ## Transfer learning
#
# faces from the wild (scraped from google images) dataset trained on top of the FER2013 model with extra added layers.
#
# Objective:
# - load the FER2013 model
# - freeze the all the layers and add appropriate amount of dense and dropout layers
# - fit the new model to FIW dataset.
# - make predictions and compare evaluations.

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.models import load_model

from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Dense, Activation, Dropout, Flatten

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt


import cv2
# Out:
# Using TensorFlow backend.

# %%
path='drive/My Drive/Facial-Expression-Detection-V2'
print(os.listdir(path))
# Out:
# ['3.jpg', 'face_crop.py', '2.jpg', '.gitignore', 'LICENSE', '1.jpg', 'haarcascade_frontalface_alt.xml', 'README.md', '.ipynb_checkpoints', 'data', 'fer2013', '.git', 'FED_FIW_local_test.ipynb', 'FED.ipynb', 'FED_transfer_local.ipynb', 'backup', 'models', 'photo.jpg', 'capture.jpg', 'FED_transfer.ipynb', 'FED_regularize.ipynb']

# %%
num_classes = 7       #angry, disgust, fear, happy, sad, surprise, neutral
# load model trained with FER2013
model_fer2013 = load_model(path+'/models/model_reg_copy.h5')#, compile=False
model_fer2013.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 48, 48, 16)        416
# _________________________________________________________________
# activation_8 (Activation)    (None, 48, 48, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 32)        4640
# _________________________________________________________________
# activation_9 (Activation)    (None, 48, 48, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_10 (Activation)   (None, 24, 24, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# activation_11 (Activation)   (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2048)              9439232
# _________________________________________________________________
# activation_12 (Activation)   (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# activation_13 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 7175
# _________________________________________________________________
# activation_14 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 11,642,503
# Trainable params: 11,642,247
# Non-trainable params: 256
# _________________________________________________________________

# %%
from keras import regularizers
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping
l2_num = 0.001



model = Sequential()
# load previous model optimised for fer2013 dataset
model.add(model_fer2013)

#fully connected neural networks
model.add(Dense(4096))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2048)) #, kernel_regularizer=regularizers.l2(l2_num)
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(l2_num)))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 7)                 11642503
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              32768
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# activation_2 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# activation_3 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 7175
# _________________________________________________________________
# activation_4 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 22,171,278
# Trainable params: 22,171,022
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# ## get faces from the wild (scraped) dataset

# %%
#------------------------------
#cpu - gpu configuration
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 8 , 'CPU': 56} ) #max: 1 gpu, 56 cpu
#sess = tf.Session(config=config) 
#keras.backend.set_session(config)
#------------------------------
# The scraped data was croped, resized and saved in FacesInTheWild.csv in the same format fer2013.csv were

with open(path+"/data/FacesInTheWild.csv") as f:
  content = f.readlines()

lines = np.array(content)

num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("instance length: ",len(lines[1].split(",")[1].split(" ")))

#------------------------------
#initialize trainset and test set
x_train, y_train, x_test, y_test = [], [], [], []

#------------------------------
#transfer train and test set data
for i in range(1,num_of_instances):
    try:
        emotion, img, usage = lines[i].split(",")
          
        val = img.split(" ")
            
        pixels = np.array(val, 'float32')
        
        emotion = keras.utils.to_categorical(emotion, num_classes)
    
        if 'Training' in usage:
            y_train.append(emotion)
            x_train.append(pixels)
        elif 'PublicTest' in usage:
            y_test.append(emotion)
            x_test.append(pixels)
    except:
      print("", end="")

#------------------------------
#data transformation for train and test sets
x_train = np.array(x_train, 'float32')
y_train = np.array(y_train, 'float32')
x_test = np.array(x_test, 'float32')
y_test = np.array(y_test, 'float32')

x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
#------------------------------
# Out:
# number of instances:  3136
# instance length:  2304
# 2200 train samples
# 935 test samples

# %%
# You can check whether a layer is trainable (or alter its setting) through the layer.trainable attribute
for layer in model.layers:
    print(layer.name, layer.trainable)
    
# Similarly, you can check how many trainable weights are in the model
print(len(model.trainable_weights))
# Out:
# sequential_2 True
# dense_1 True
# activation_1 True
# dropout_1 True
# dense_2 True
# activation_2 True
# dropout_2 True
# dense_3 True
# activation_3 True
# dropout_3 True
# dense_4 True
# activation_4 True
# 24

# %%
model_fer2013.trainable = False

# %%
# You can check whether a layer is trainable (or alter its setting) through the layer.trainable attribute
for layer in model.layers:
    print(layer.name, layer.trainable)
    
# Similarly, we can check how many trainable weights are in the model
print(len(model.trainable_weights))
# Out:
# sequential_2 False
# dense_1 True
# activation_1 True
# dropout_1 True
# dense_2 True
# activation_2 True
# dropout_2 True
# dense_3 True
# activation_3 True
# dropout_3 True
# dense_4 True
# activation_4 True
# 8

# %% [markdown]
# ## train the model for FIW dataset

# %%
#variables
batch_size = 256
epochs = 50

#------------------------------
#batch process
gen = ImageDataGenerator(zoom_range=0.3)
train_generator = gen.flow(x_train, y_train, batch_size=batch_size)
test_generator = gen.flow(x_test, y_test, batch_size=batch_size)

#------------------------------

model.compile(loss='categorical_crossentropy'
    , optimizer=keras.optimizers.Adam()
    , metrics=['accuracy']
)

#------------------------------

fit = False

if fit == False:
    #model.fit_generator(x_train, y_train, epochs=epochs) #train for all trainset
    history = model.fit_generator(train_generator, steps_per_epoch=batch_size, epochs=epochs, 
                                  validation_data=test_generator) #train for randomly selected one
    model.save(path+'/data/model_FIW.h5')
    
else:
    model = load_model(path+'/models/model_FIW.h5') #load weights from the faces in the wild optimized
# Out:
# Epoch 1/50
# 256/256 [==============================] - 282s 1s/step - loss: 1.8715 - accuracy: 0.3917 - val_loss: 1.8307 - val_accuracy: 0.3850
# Epoch 2/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8467 - accuracy: 0.3965 - val_loss: 1.8894 - val_accuracy: 0.3818
# Epoch 3/50
# 256/256 [==============================] - 292s 1s/step - loss: 1.8439 - accuracy: 0.3975 - val_loss: 1.8075 - val_accuracy: 0.3968
# Epoch 4/50
# 256/256 [==============================] - 291s 1s/step - loss: 1.8404 - accuracy: 0.4030 - val_loss: 1.8698 - val_accuracy: 0.3829
# Epoch 5/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8370 - accuracy: 0.4031 - val_loss: 1.8254 - val_accuracy: 0.3679
# Epoch 6/50
# 256/256 [==============================] - 281s 1s/step - loss: 1.8342 - accuracy: 0.3997 - val_loss: 1.7922 - val_accuracy: 0.3914
# Epoch 7/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8333 - accuracy: 0.4020 - val_loss: 1.9024 - val_accuracy: 0.3829
# Epoch 8/50
# 256/256 [==============================] - 282s 1s/step - loss: 1.8284 - accuracy: 0.4052 - val_loss: 1.8750 - val_accuracy: 0.3914
# Epoch 9/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8338 - accuracy: 0.4028 - val_loss: 1.8924 - val_accuracy: 0.3829
# Epoch 10/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8290 - accuracy: 0.4041 - val_loss: 1.8415 - val_accuracy: 0.3904
# Epoch 11/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8285 - accuracy: 0.4052 - val_loss: 1.8888 - val_accuracy: 0.3829
# Epoch 12/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8323 - accuracy: 0.4021 - val_loss: 1.7218 - val_accuracy: 0.3957
# Epoch 13/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8273 - accuracy: 0.4036 - val_loss: 1.8279 - val_accuracy: 0.3893
# Epoch 14/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8262 - accuracy: 0.4029 - val_loss: 1.8930 - val_accuracy: 0.3872
# Epoch 15/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8277 - accuracy: 0.4034 - val_loss: 1.7676 - val_accuracy: 0.4096
# Epoch 16/50
# 256/256 [==============================] - 282s 1s/step - loss: 1.8266 - accuracy: 0.4029 - val_loss: 1.8201 - val_accuracy: 0.3904
# Epoch 17/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8262 - accuracy: 0.4044 - val_loss: 1.8436 - val_accuracy: 0.3904
# Epoch 18/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8230 - accuracy: 0.4056 - val_loss: 1.8620 - val_accuracy: 0.4053
# Epoch 19/50
# 256/256 [==============================] - 281s 1s/step - loss: 1.8273 - accuracy: 0.4066 - val_loss: 1.7588 - val_accuracy: 0.3936
# Epoch 20/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8237 - accuracy: 0.4038 - val_loss: 1.8444 - val_accuracy: 0.3925
# Epoch 21/50
# 256/256 [==============================] - 283s 1s/step - loss: 1.8214 - accuracy: 0.4038 - val_loss: 1.7993 - val_accuracy: 0.3840
# Epoch 22/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8217 - accuracy: 0.4026 - val_loss: 1.8203 - val_accuracy: 0.3914
# Epoch 23/50
# 256/256 [==============================] - 284s 1s/step - loss: 1.8208 - accuracy: 0.4069 - val_loss: 1.7874 - val_accuracy: 0.4075
# Epoch 24/50
# 256/256 [==============================] - 279s 1s/step - loss: 1.8208 - accuracy: 0.4059 - val_loss: 1.8495 - val_accuracy: 0.3893
# Epoch 25/50
# 256/256 [==============================] - 280s 1s/step - loss: 1.8188 - accuracy: 0.4063 - val_loss: 1.8194 - val_accuracy: 0.3872
# Epoch 26/50
# 256/256 [==============================] - 282s 1s/step - loss: 1.8185 - accuracy: 0.4059 - val_loss: 1.8008 - val_accuracy: 0.4128
# Epoch 27/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8202 - accuracy: 0.4069 - val_loss: 1.7237 - val_accuracy: 0.3850
# Epoch 28/50
# 256/256 [==============================] - 275s 1s/step - loss: 1.8232 - accuracy: 0.4053 - val_loss: 1.8822 - val_accuracy: 0.3979
# Epoch 29/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8207 - accuracy: 0.4059 - val_loss: 1.8731 - val_accuracy: 0.3786
# Epoch 30/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8215 - accuracy: 0.4056 - val_loss: 1.8766 - val_accuracy: 0.3797
# Epoch 31/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8205 - accuracy: 0.4072 - val_loss: 1.8207 - val_accuracy: 0.4000
# Epoch 32/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8189 - accuracy: 0.4061 - val_loss: 1.9237 - val_accuracy: 0.3957
# Epoch 33/50
# 256/256 [==============================] - 281s 1s/step - loss: 1.8199 - accuracy: 0.4065 - val_loss: 1.8842 - val_accuracy: 0.4043
# Epoch 34/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8204 - accuracy: 0.4047 - val_loss: 1.8097 - val_accuracy: 0.3850
# Epoch 35/50
# 256/256 [==============================] - 291s 1s/step - loss: 1.8181 - accuracy: 0.4069 - val_loss: 1.8918 - val_accuracy: 0.4075
# Epoch 36/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8170 - accuracy: 0.4093 - val_loss: 1.8130 - val_accuracy: 0.3893
# Epoch 37/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8178 - accuracy: 0.4056 - val_loss: 1.8341 - val_accuracy: 0.3936
# Epoch 38/50
# 256/256 [==============================] - 280s 1s/step - loss: 1.8161 - accuracy: 0.4056 - val_loss: 1.9213 - val_accuracy: 0.3936
# Epoch 39/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8150 - accuracy: 0.4087 - val_loss: 1.8622 - val_accuracy: 0.3872
# Epoch 40/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8160 - accuracy: 0.4057 - val_loss: 1.8074 - val_accuracy: 0.3989
# Epoch 41/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8181 - accuracy: 0.4054 - val_loss: 1.8071 - val_accuracy: 0.3840
# Epoch 42/50
# 256/256 [==============================] - 281s 1s/step - loss: 1.8154 - accuracy: 0.4056 - val_loss: 1.8054 - val_accuracy: 0.4096
# Epoch 43/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8147 - accuracy: 0.4081 - val_loss: 1.8193 - val_accuracy: 0.4021
# Epoch 44/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8174 - accuracy: 0.4072 - val_loss: 1.8516 - val_accuracy: 0.3893
# Epoch 45/50
# 256/256 [==============================] - 278s 1s/step - loss: 1.8191 - accuracy: 0.4064 - val_loss: 1.8469 - val_accuracy: 0.3840
# Epoch 46/50
# 256/256 [==============================] - 281s 1s/step - loss: 1.8153 - accuracy: 0.4054 - val_loss: 1.8607 - val_accuracy: 0.3850
# Epoch 47/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8174 - accuracy: 0.4045 - val_loss: 1.8615 - val_accuracy: 0.3861
# Epoch 48/50
# 256/256 [==============================] - 277s 1s/step - loss: 1.8158 - accuracy: 0.4062 - val_loss: 1.8041 - val_accuracy: 0.3968
# Epoch 49/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8154 - accuracy: 0.4076 - val_loss: 1.8054 - val_accuracy: 0.3968
# Epoch 50/50
# 256/256 [==============================] - 276s 1s/step - loss: 1.8144 - accuracy: 0.4083 - val_loss: 1.8220 - val_accuracy: 0.3968

# %% [markdown]
# ### **Evaluate the FIW Model**

# %%
#Evaluation
train_score = model.evaluate(x_train, y_train, verbose=1)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])
 
test_score = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# 2200/2200 [==============================] - 12s 5ms/step
# Train loss: 1.7274033596298912
# Train accuracy: 43.95454525947571
# 935/935 [==============================] - 3s 4ms/step
# Test loss: 1.8270406687960905
# Test accuracy: 40.855616331100464

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))

    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')

    plt.show()

# %%
monitor_testset_results = True

if monitor_testset_results == True:
	#make predictions for test set
	predictions = model.predict(x_test)

	index = 0
	for i in predictions:
		if index < 20 and index >= 10:
			#print(i) #predicted scores
			#print(y_test[index]) #actual scores
			
			testing_img = np.array(x_test[index], 'float32')
			testing_img = testing_img.reshape([48, 48]);
			
			plt.gray()
			plt.imshow(testing_img)
			plt.show()
			
			print(i)
			
			emotion_analysis(i)
			print("----------------------------------------------")
		index = index + 1
# Out:
# [0.7233793  0.20881888 0.01123016 0.00666722 0.03251074 0.00811222
#  0.00928139]
# ----------------------------------------------
# [0.09718626 0.0655428  0.24479857 0.03719088 0.06808328 0.42354074
#  0.0636575 ]
# ----------------------------------------------
# [0.3128056  0.22614473 0.10783711 0.04389032 0.1695146  0.03578044
#  0.10402715]
# ----------------------------------------------
# [0.04267755 0.05745232 0.03229268 0.653398   0.02009956 0.11297817
#  0.08110181]
# ----------------------------------------------
# [0.33625197 0.37177384 0.06973869 0.03216019 0.1052442  0.02959615
#  0.05523501]
# ----------------------------------------------
# [0.1689387  0.22412464 0.13604231 0.06037965 0.19308366 0.16981295
#  0.04761808]
# ----------------------------------------------
# [0.3811222  0.16185357 0.02442452 0.24148007 0.04574247 0.0772159
#  0.06816123]
# ----------------------------------------------
# [0.21107897 0.15047911 0.13145657 0.05298221 0.24005015 0.02866517
#  0.1852878 ]
# ----------------------------------------------
# [0.28620517 0.23601493 0.03727037 0.16520786 0.08065768 0.09828182
#  0.09636223]
# ----------------------------------------------
# [0.55662096 0.36634463 0.01139208 0.00275297 0.04305163 0.00298508
#  0.01685268]
# ----------------------------------------------

# %%
#Confusion Matrix.

from sklearn.metrics import classification_report, confusion_matrix
 
pred_list = []; actual_list = []
 
for i in predictions:
  pred_list.append(np.argmax(i))


for i in y_test: 
  actual_list.append(np.argmax(i))



cm = confusion_matrix(actual_list, pred_list)
cm
# Out:
# array([[ 70,  15,   3,  11,  25,  19,  10],
#        [ 38,  29,   6,  22,  24,  16,   8],
#        [ 14,  14,   3,   7,  22,  28,   8],
#        [  9,  14,   1,  83,   5,  24,   5],
#        [ 21,  15,   1,  12,  54,   8,  13],
#        [ 11,   3,   0,   8,  15, 117,   4],
#        [ 21,  12,   1,  14,  25,  21,  26]])

# %%
import itertools
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
title='Confusion matrix'

plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels, rotation=45)
plt.yticks(tick_marks, labels)
fmt = 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epch = range(1, len(train_acc) + 1)
plt.plot(epch, train_acc, 'g.', label='Training Accuracy')
plt.plot(epch, val_acc, 'g', label='Validation acc')
plt.title('Accuracy')
plt.legend()
plt.figure()
plt.plot(epch, train_loss, 'r.', label='Training loss')
plt.plot(epch, val_loss, 'r', label='Validation loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
#plot face function
def plotface(file):
  #file = path+'/1.jpg'
  true_image = image.load_img(file)
  img = image.load_img(file, grayscale=True, target_size=(48, 48))

  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  x /= 255

  custom = model.predict(x)
  emotion_analysis(custom[0])

  x = np.array(x, 'float32')
  x = x.reshape([48, 48]);

  plt.gray()
  plt.imshow(true_image)
  plt.show()

# %%
def facecrop(image):  
    """
    Use pretrained HAAR cascade to detect the face and build a bounding box 
    """
    facedata = '/content/drive/My Drive/Facial-Expression-Detection-V2/haarcascade_frontalface_alt.xml'
    #facedata = path+"/haarcascade_frontalface_default.xml"
    cascade = cv2.CascadeClassifier(facedata)

    img = cv2.imread(image)

    try:
    
        minisize = (img.shape[1],img.shape[0])
        miniframe = cv2.resize(img, minisize)

        faces = cascade.detectMultiScale(miniframe)

        for f in faces:
            x, y, w, h = [ v for v in f ]
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

            sub_face = img[y:y+h, x:x+w]

            
            cv2.imwrite(path+'/capture.jpg', sub_face)
            print ("Writing: " + image)

    except Exception as e:
        print (e)

    #cv2.imshow(image, img)
    plt.imshow(img)


facecrop(path+'/1.jpg')
# Out:
# Writing: drive/My Drive/Facial-Expression-Detection-V2/1.jpg

# %%
plotface(path+'/capture.jpg')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
#CODE for Capturing an image on Colab from here: https://colab.research.google.com/notebook#fileId=1OnUy6eFE7XhdfGfAHDCqQxpwueTOj_NO

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename=path+'/photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)
    return filename

# %%
take_photo()
# Out:
# 'drive/My Drive/Facial-Expression-Detection-V2/photo.jpg'

# %%
#Test the captured image
facecrop(path+'/photo.jpg')
# Out:
# Writing: drive/My Drive/Facial-Expression-Detection-V2/photo.jpg

# %%
plotface(path+'/capture.jpg')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %% [markdown]
# ## conclusion
#
# - training model with relatively small image sample scraped from google images does not improve the accuracy
# - Building the model on top of FER2013 model may not be a good strategy. Fer2013 dataset is well curated and of high quality compared to the images scraped from google images.
# - have more "well labeled" image set may improve the model
